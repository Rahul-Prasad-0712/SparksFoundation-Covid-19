# %% [markdown]
# # THE SPARKS FOUNDATION - GRIP DECEMBER 2022

# %% [markdown]
# ## Data Science And Business Analytics Internship

# %% [markdown]
# ## Timeline Analysis : Covid - 19

# %% [markdown]
# ## Author:- Rahul Prasad

# %% [markdown]
# ### Task 8:- Create a storyboard showing spread of covid- 19 cases in your country or any region (Asia,Europe, BRICS etc) using Tableau Power BI or SAP

# %% [markdown]
# ## Step 1:- Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Step 2:- Loading The Data

# %%
df = pd.read_csv('owid-covid-data.csv')
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ## Step 3:- Data Exploration

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.277780e+05  2.274430e+05        2.262440e+05  2.083890e+05
# mean   4.794234e+06  1.217074e+04        1.219851e+04  7.647545e+04
# std    2.978261e+07  8.391748e+04        8.192282e+04  3.916994e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    4.981000e+03  0.000000e+00        5.429000e+00  1.180000e+02
# 50%    5.577200e+04  4.700000e+01        8.728600e+01  1.264000e+03
# 75%    5.722170e+05  9.090000e+02        1.080429e+03  1.037900e+04
# max    6.487046e+08  4.083954e+06        3.439393e+06  6.652105e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  208297.000000        207113.000000            226740.000000
# mean      132.695065           133.296570             65659.020787
# std       712.179935           697.827016            114183.980202
# min         0.000000             0.000000                 0.001000
# 25%         0.000000             0.000000              1179.676750
# 50%         1.000000             1.286000             11557.888000
# 75%        13.000000            14.714000             78456.485500
# max     17733.000000         14859.286000            694304.844000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          226405.000000                   225211.000000
# mean              185.820935                      186.142577
# std              1159.847347                      687.176149
# min                 0.000000                        0.000000
# 25%                 0.000000                        1.166000
# 50%                 6.317000                       17.864000
# 75%                91.850000                      130.910000
# max            228872.025000                    36421.827000
#
#        total_deaths_per_million  ...   male_smokers  handwashing_facilities  \
# count             207364.000000  ...  145216.000000            95709.000000
# mean                 715.326606  ...      32.814748               50.894028
# std                  997.344495  ...      13.536756               31.873966
# min                    0.000000  ...       7.700000                1.188000
# 25%                   31.846000  ...      21.600000               20.859000
# 50%                  226.603000  ...      33.100000               49.839000
# 75%                 1060.716000  ...      41.300000               83.241000
# max                 6391.737000  ...      78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count               173050.000000    221752.000000            189693.000000
# mean                     3.088137        73.611952                 0.724683
# std                      2.551418         7.446506                 0.149599
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.500000                 0.602000
# 50%                      2.500000        75.050000                 0.742000
# 75%                      4.200000        79.070000                 0.838000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  2.407050e+05                          8.087000e+03
# mean   1.408269e+08                          4.977151e+04
# std    6.925010e+08                          1.370660e+05
# min    4.700000e+01                         -3.772610e+04
# 25%    8.367830e+05                          5.320000e+01
# 50%    6.948395e+06                          6.301800e+03
# 75%    3.369661e+07                          3.612080e+04
# max    7.975105e+09                          1.240683e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  8087.000000       8116.000000
# mean                     10.085970         14.215795
# std                      13.403121         26.063144
# min                     -28.450000        -95.920000
# 25%                       0.740000          0.030000
# 50%                       7.640000          7.415000
# 75%                      15.770000         19.392500
# max                      76.550000        376.710000
#
#        excess_mortality_cumulative_per_million
# count                              8087.000000
# mean                               1411.092772
# std                                1778.219605
# min                               -1984.281517
# 25%                                  37.336276
# 50%                                 852.109416
# 75%                                2261.224282
# max                               10032.844512
#
# [8 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241743 entries, 0 to 241742
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    241743 non-null  object
#  1   continent                                   228147 non-null  object
#  2   location                                    241743 non-null  object
#  3   date                                        241743 non-null  object
#  4   total_cases                                 227778 non-null  float64
#  5   new_cases                                   227443 non-null  float64
#  6   new_cases_smoothed                          226244 non-null  float64
#  7   total_deaths                                208389 non-null  float64
#  8   new_deaths                                  208297 non-null  float64
#  9   new_deaths_smoothed                         207113 non-null  float64
#  10  total_cases_per_million                     226740 non-null  float64
#  11  new_cases_per_million                       226405 non-null  float64
#  12  new_cases_smoothed_per_million              225211 non-null  float64
#  13  total_deaths_per_million                    207364 non-null  float64
#  14  new_deaths_per_million                      207272 non-null  float64
#  15  new_deaths_smoothed_per_million             206093 non-null  float64
#  16  reproduction_rate                           178577 non-null  float64
#  17  icu_patients                                32726 non-null   float64
#  18  icu_patients_per_million                    32726 non-null   float64
#  19  hosp_patients                               35711 non-null   float64
#  20  hosp_patients_per_million                   35711 non-null   float64
#  21  weekly_icu_admissions                       8115 non-null    float64
#  22  weekly_icu_admissions_per_million           8115 non-null    float64
#  23  weekly_hosp_admissions                      19410 non-null   float64
#  24  weekly_hosp_admissions_per_million          19410 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          68674 non-null   float64
#  35  people_vaccinated                           65656 non-null   float64
#  36  people_fully_vaccinated                     63007 non-null   float64
#  37  total_boosters                              37902 non-null   float64
#  38  new_vaccinations                            56946 non-null   float64
#  39  new_vaccinations_smoothed                   143542 non-null  float64
#  40  total_vaccinations_per_hundred              68674 non-null   float64
#  41  people_vaccinated_per_hundred               65656 non-null   float64
#  42  people_fully_vaccinated_per_hundred         63007 non-null   float64
#  43  total_boosters_per_hundred                  37902 non-null   float64
#  44  new_vaccinations_smoothed_per_million       143542 non-null  float64
#  45  new_people_vaccinated_smoothed              143224 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  143224 non-null  float64
#  47  stringency_index                            179198 non-null  float64
#  48  population_density                          210597 non-null  float64
#  49  median_age                                  194805 non-null  float64
#  50  aged_65_older                               192750 non-null  float64
#  51  aged_70_older                               193786 non-null  float64
#  52  gdp_per_capita                              194336 non-null  float64
#  53  extreme_poverty                             126604 non-null  float64
#  54  cardiovasc_death_rate                       194255 non-null  float64
#  55  diabetes_prevalence                         204356 non-null  float64
#  56  female_smokers                              147231 non-null  float64
#  57  male_smokers                                145216 non-null  float64
#  58  handwashing_facilities                      95709 non-null   float64
#  59  hospital_beds_per_thousand                  173050 non-null  float64
#  60  life_expectancy                             221752 non-null  float64
#  61  human_development_index                     189693 non-null  float64
#  62  population                                  240705 non-null  float64
#  63  excess_mortality_cumulative_absolute        8087 non-null    float64
#  64  excess_mortality_cumulative                 8087 non-null    float64
#  65  excess_mortality                            8116 non-null    float64
#  66  excess_mortality_cumulative_per_million     8087 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 123.6+ MB

# %% [markdown]
# ## Step 4:- Dropping the duplicate rows

# %%
df.shape
# Out:
# (241743, 67)

# %%
duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 67)

# %%
df.count()
# Out:
# iso_code                                   241743
# continent                                  228147
# location                                   241743
# date                                       241743
# total_cases                                227778
#                                             ...
# population                                 240705
# excess_mortality_cumulative_absolute         8087
# excess_mortality_cumulative                  8087
# excess_mortality                             8116
# excess_mortality_cumulative_per_million      8087
# Length: 67, dtype: int64

# %% [markdown]
# ## Step 5:- Checking the Missing or Null Values

# %%
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                   13596
# location                                        0
# date                                            0
# total_cases                                 13965
#                                             ...
# population                                   1038
# excess_mortality_cumulative_absolute       233656
# excess_mortality_cumulative                233656
# excess_mortality                           233627
# excess_mortality_cumulative_per_million    233656
# Length: 67, dtype: int64

# %%
df1 = df[['date','total_cases','new_cases','total_deaths','new_tests','total_tests']]
df1.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_tests  total_tests
# 0  2020-02-24          5.0        5.0           NaN        NaN          NaN
# 1  2020-02-25          5.0        0.0           NaN        NaN          NaN
# 2  2020-02-26          5.0        0.0           NaN        NaN          NaN
# 3  2020-02-27          5.0        0.0           NaN        NaN          NaN
# 4  2020-02-28          5.0        0.0           NaN        NaN          NaN

# %%
df1.date = pd.to_datetime(df.date)
df1.set_index('date', inplace = True)
# Out:
# C:\Users\Rahul Prasad\AppData\Local\Temp\ipykernel_38368\1558376842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.date = pd.to_datetime(df.date)

# %%
df1.head()
# Out:
#             total_cases  new_cases  total_deaths  new_tests  total_tests
# date
# 2020-02-24          5.0        5.0           NaN        NaN          NaN
# 2020-02-25          5.0        0.0           NaN        NaN          NaN
# 2020-02-26          5.0        0.0           NaN        NaN          NaN
# 2020-02-27          5.0        0.0           NaN        NaN          NaN
# 2020-02-28          5.0        0.0           NaN        NaN          NaN

# %% [markdown]
# ## Step 6:- Data Visualization

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_cases.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_deaths.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.new_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %%
df1.total_tests.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20)
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# ## Step 7:- Trends And Seasonality in TimeSeries Data

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_cases = df1[['new_cases']]
new_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_deaths = df1[['total_deaths']]
total_deaths.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
new_tests = df1[['new_tests']]
new_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_tests = df1[['total_tests']]
total_tests.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
total_cases = df1[['total_cases']]
total_cases.rolling(12).mean().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %%
df_rm = pd.concat([total_cases.rolling(12).mean(), total_deaths.rolling(12).mean()])
df_rm.plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month' , fontsize = 20);

# %% [markdown]
# ## Step 8:- Seasonal Patterns In Time Series Data

# %%
total_cases.diff().plot(figsize = (20 , 10), linewidth = 5, fontsize = 20)
plt.xlabel('Month', fontsize = 20);
